# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
# Для изображения частотных графиков можно использовать sns.distplot или plt.hist

# %%
plt.hist(data.CRIM, 20, color='g')
# или
# sns.distplot(data.CRIM, kde = False)

plt.xlabel('CRIM')
plt.ylabel('frequency')
plt.title('Частотный график CRIM (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Геометрическое распределение (график выше)

# %%
plt.hist(data.ZN, 20, color='b')
# или
# sns.distplot(data.ZN, kde = False)

plt.xlabel('ZN')
plt.ylabel('frequency')
plt.title('Частотный график ZN (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Ближе к геометрическому распределению, но четкого распределения нет (график выше)

# %%
plt.hist(data.INDUS, 20, color='y')
# или
# sns.distplot(data.INDUS, kde = False)

plt.xlabel('INDUS')
plt.ylabel('frequency')
plt.title('Частотный график INDUS (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Нет четкого распределения (график выше)

# %%
plt.hist(data.CHAS, 20, color='r')
# или
# sns.distplot(data.CHAS, kde = False)

plt.xlabel('CHAS')
plt.ylabel('frequency')
plt.title('Частотный график CHAS (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Распределение Бернулли (график выше)

# %%
plt.hist(data.NOX, 10, color='violet')
# или
# sns.distplot(data.NOX, kde = False)

plt.xlabel('NOX')
plt.ylabel('frequency')
plt.title('Частотный график NOX (разбиение интервала на 10 элементов)')
plt.grid(True)
plt.show()

# %%
# Ближе всего к логнормальному распределению, но не четко (график выше)

# %%
plt.hist(data.RM, 20, color='black')
# или
# sns.distplot(data.RM, kde = False)

plt.xlabel('RM')
plt.ylabel('frequency')
plt.title('Частотный график RM (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Нормальное распределение (график выше)

# %%
plt.hist(data.AGE, 20, color='brown')
# или
# sns.distplot(data.AGE, kde = False)

plt.xlabel('AGE')
plt.ylabel('frequency')
plt.title('Частотный график AGE (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Обратное геометрическое распределение? (график выше)

# %%
plt.hist(data.TAX, 20, color='gray')
# или
# sns.distplot(data.TAX, kde = False)

plt.xlabel('TAX')
plt.ylabel('frequency')
plt.title('Частотный график TAX (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Нет четкого распределения (график выше)

# %%
plt.hist(data.DIS, 20, color='orange')
# или
# sns.distplot(data.DIS, kde = False)

plt.xlabel('DIS')
plt.ylabel('frequency')
plt.title('Частотный график DIS (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Логнормальное распределение (график выше)

# %%
plt.hist(data.RAD, 20, color='purple')
# или
# sns.distplot(data.RAD, kde = False)

plt.xlabel('RAD')
plt.ylabel('frequency')
plt.title('Частотный график RAD (разбиение интервала на 3 элемента)')
plt.grid(True)
plt.show()

# %%
# Нет четкого распределения (график выше)

# %%
plt.hist(data.TAX, 20, color='gray')
# или
# sns.distplot(data.TAX, kde = False)

plt.xlabel('TAX')
plt.ylabel('frequency')
plt.title('Частотный график TAX (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Нет четкого распределения (график выше)

# %%
plt.hist(data.PTRATIO, 20, color='b')
# или
# sns.distplot(data.PTRATIO, kde = False)

plt.xlabel('PTRATIO')
plt.ylabel('frequency')
plt.title('Частотный график PTRATIO (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Ближе к обратному логнормальному распределению? (график выше)

# %%
plt.hist(data.B, 20, color='r')
# или
# sns.distplot(data.B, kde = False)

plt.xlabel('B')
plt.ylabel('frequency')
plt.title('Частотный график B (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Обратное геометрическое распределение? (график выше)

# %%
plt.hist(data.LSTAT, 20, color='violet')
# или
# sns.distplot(data.LSTAT, kde = False)

plt.xlabel('LSTAT')
plt.ylabel('frequency')
plt.title('Частотный график LSTAT (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Логнормальное распределение (график выше)

# %%
plt.hist(data.MEDV, 20, color='purple')
# или
# sns.distplot(data.MEDV, kde = False)

plt.xlabel('MEDV')
plt.ylabel('frequency')
plt.title('Частотный график MEDV (разбиение интервала на 20 элементов)')
plt.grid(True)
plt.show()

# %%
# Ближе к биномиальному распределению (график выше)

# %% [markdown]
# Построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут).

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(12,12)
plt.show()

# %%
# Наибольшая корреляция (+0,91) наблюдается между RAD и TAX, что интересно, поскольку:
# RAD - доступность радиальных автомобильных магистралей, а TAX - налог на недвижимость.

# С ценой дома (MEDV) больше всего прямо коррелирует среднее количество комнат (RM),
# а наибольшая обратная корреляция цены дома видна с долей бедного населения (LSTAT).

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
# Для sklearn сделаем reshape(-1,1) и преобразуем данные в numpy array

median_value = np.array(data.MEDV).reshape(-1,1)
lower_status = np.array(data.LSTAT).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Разделим данные на 80% тренировочных и на 20% тестовых

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    median_value,
    lower_status,
    test_size = 0.2
)

# %%
# Обучим модель с помощью fit() метода

model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Посмотрим предсказания модели на тестируемых данных

predicted_y = model.predict(X_test)

# %%
# Посчитаем ошибку модели на тестовых данных

from sklearn.metrics import mean_squared_error, mean_absolute_error

print('Абсолютная ошибка модели:', mean_absolute_error(predicted_y, y_test))
print('Среднеквадратичная ошибка модели:', mean_squared_error(predicted_y, y_test))
# Out:
# Абсолютная ошибка модели: 3.5884745633101107
# Среднеквадратичная ошибка модели: 21.258314696839772

# %%
plt.xlabel('Стоимость дома')
plt.ylabel('Доля бедного населения')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(-100, 5000, 100)
# Посчитаем предсказанные значения
# y = kx + b
# k = model.coef_
# b = model.intercept_
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(X_train, y_train, 'r.')
plt.plot(X_test, y_test, 'b.')
plt.xlim(0,55)
plt.ylim(0,45)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()

# %%
# Получаем обратную зависимость двух переменных: чем выше доля бедного населения, тем ниже стоимость дома

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %%
# Количество отсутвующих значений (NaN) во всем датасете

print('Количество отсутствующих значений (NaN) во всем датасете:', data.isnull().sum().sum())
# Out:
# Количество отсутствующих значений (NaN) во всем датасете: 23

# %%
# Количество отсутствующих значений (NaN) в выборке Country (region)

print('Количество отсутствующих значений (NaN) в выборке Country (region):', data['Country (region)'].isnull().sum())

# Если бы были отсутствующие значения, можно было убрать с помощью data['Country (region)'].dropna(inplace=True)
# Out:
# Количество отсутствующих значений (NaN) в выборке Country (region): 0

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
len(data['Country (region)'].unique())
# Out:
# 156

# %%
len(data['Country (region)'])
# Out:
# 156

# %%
# Страны не повторялись, поэтому можно использовать оба варианта.

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(8,8)
plt.show()

# %%
# По матрице видно, что максимальная прямая корреляция имеется между:
# уровнем в рейтинге и социальной поддержкой;
# уровнем в рейтинге и ВВП на душу населения;
# уровнем в рейтинге и ожиданием здоровой жизни;
# ВВП на душу населения и ожиданием здоровой жизни.

# По матрице также видно, что максимальная обратная корреляция имеется между:
# позитивным эффектом и стандартным отклонением уровня в рейтинге

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
import random

# plt.hist([random.randint(1,6) for i in range(10)], 6)
# или
sns.distplot([random.randint(1,6) for i in range(10)], kde = False, bins = 6)

plt.xlabel('Результаты подбрасывания игрального кубика')
plt.ylabel('Частота выпадения')
plt.title('Частотный график результатов подбрасывания игрального кубика после 10 раз')
plt.grid(True)
plt.show()

# %%
# Распределение должно стремиться к равномерному, но на 10 повторениях это не прослеживается

# %%
# Для наглядности также справочно приведем частотный график результатов подбрасывания игрального кубика 1000 раз

# plt.hist([random.randint(1,6) for i in range(1000)], 6)
# или
sns.distplot([random.randint(1,6) for i in range(1000)], kde = False, bins = 6)

plt.xlabel('Результаты подбрасывания игрального кубика')
plt.ylabel('Частота выпадения')
plt.title('Частотный график результатов подбрасывания игрального кубика 1000 раз')
plt.grid(True)
plt.show()

# %%
# Здесь уже визуально абсолютно очевидно равномерное распределение

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %%
# Подбрасываем кубик 100 раз и считаем сумму выпавших чисел. Затем повторяем это 1000 раз. Создаем список из результатов.
# Получаем список тысячи сумм

list_of_1000_sums = [sum([random.randint(1,6) for i in range(100)]) for sum_ in range(1000)]

# Чертим гистограмму на основании полученных данных

# plt.hist(list_of_1000_sums, 10)
# или
sns.distplot(list_of_1000_sums, kde = True, bins = 20)

plt.xlabel('Сумма ста подбрасываний')
plt.ylabel('Частота')
plt.title('Частотный график сумм подбрасывания игрального кубика 100 раз после 1000 повторений')
plt.grid(True)
plt.show()

# %%
# Налицо нормальное распределение, что отвечает принипу центральной предельной теоремы.
# Графики отличаются, потому что на них отражены принципипльно разные значения:
# в первом случае мы отображали количество выпадений конкретного числа (стремится к равномерному распределению),
# а во втором - тысячу результатов суммирования ста выпадений (стремится к нормальному распределению).
